# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = y = np.arange(-10, 10, 0.3)
X, Y = np.meshgrid(x, y)

mu = np.array([0,0])
# sigma = np.array([[2, 1], 
#                   [1, 4]])

sigma = np.array([[10, 0], 
                  [0, 10]])

det = np.linalg.det(sigma)
inv_sigma = np.linalg.inv(sigma)

def gauss_2d(x, y):
    x_c = np.array([x, y]) - mu
    return np.exp(- x_c.dot(inv_sigma).dot(x_c[np.newaxis, :].T) / 2.0) / (2*np.pi*np.sqrt(det))

Z = np.vectorize(gauss_2d)(X, Y)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(x, y)

mu = np.array([0,0])
# sigma = np.array([[1, 0], 
#                   [0, 1]])

sigma = np.array([[2, 1], 
                  [1, 4]])

det = np.linalg.det(sigma)
inv_sigma = np.linalg.inv(sigma)

def gauss_2d(x, y):
    x_c = np.array([x, y]) - mu
    return np.exp(- x_c.dot(inv_sigma).dot(x_c[np.newaxis, :].T) / 2.0) / (2*np.pi*np.sqrt(det))

Z = np.vectorize(gauss_2d)(X, Y)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()

# %%
sigma
# Out:
# array([[2, 1],
#        [1, 4]])

# %%
np.linalg.eig(sigma)
# Out:
# (array([ 1.58578644,  4.41421356]), array([[-0.92387953, -0.38268343],
#         [ 0.38268343, -0.92387953]]))

# %%
inv_sigma
# Out:
# array([[ 0.57142857, -0.14285714],
#        [-0.14285714,  0.28571429]])

# %%
w, v = np.linalg.eig(inv_sigma)

# %%
w
# Out:
# array([ 0.63060194,  0.22654092])

# %%
v
# Out:
# array([[ 0.92387953,  0.38268343],
#        [-0.38268343,  0.92387953]])

# %%
np.linalg.eig?

# %%
A = np.array([[10,5],[5,10]])
w_, v_ = np.linalg.eig(A)

# %%
w_
# Out:
# array([ 15.,   5.])

# %%
v_
# Out:
# array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]])

# %%
sigma
# Out:
# array([[2, 1],
#        [1, 4]])

# %%
w, v = np.linalg.eig(sigma)

# %%
v
# Out:
# array([[-0.92387953, -0.38268343],
#        [ 0.38268343, -0.92387953]])

# %% [markdown]
# # 問題1

# %%
import numpy as np
n = 1000

# %%
import numpy as np
n = 1000

x = np.random.randn(n)
y1 = x + np.random.randn(n)
y2 = -x + np.random.randn(n)
y3 = np.random.randn(n)
y4 = x**2 + np.random.randn(n)

print(np.corrcoef(x, y1)[0, 1])
print(np.corrcoef(x, y2)[0, 1])
print(np.corrcoef(x, y3)[0, 1])
print(np.corrcoef(x, y4)[0, 1])
# Out:
# 0.729195186123
# -0.731054853932
# 0.020960020396
# 0.0511090973279

# %%
np.corrcoef(x, y1)[0, 1]
# Out:
# 0.71104472543215402
